# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7a767762bfcd804be7691c6640aa864

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_url = url + "&q=" + city.replace(" ","+")
test = requests.get(city_url).json()
rain= test["weather"][0]["description"]
rain
# Out:
# 'light rain'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        print('wait')

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                          "description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | luderitz
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | norman wells
# Processing Record 7 of Set 1 | capinopolis
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | dwarka
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | wanning
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | paris
# Processing Record 17 of Set 1 | vitkov
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | konstantinovka
# Processing Record 20 of Set 1 | ixtapa
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | hobyo
# Processing Record 23 of Set 1 | isangel
# Processing Record 24 of Set 1 | lavrentiya
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | gwadar
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | aklavik
# Processing Record 31 of Set 1 | guerrero negro
# Processing Record 32 of Set 1 | hailar
# Processing Record 33 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | loubomo
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | shelburne
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | kawalu
# Processing Record 41 of Set 1 | antalaha
# Processing Record 42 of Set 1 | leshukonskoye
# Processing Record 43 of Set 1 | saint anthony
# Processing Record 44 of Set 1 | bathsheba
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | zaraza
# Processing Record 47 of Set 1 | los llanos de aridane
# Processing Record 48 of Set 1 | yar-sale
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | nuuk
# wait
# Processing Record 1 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 2 | mecca
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | houma
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | karlskrona
# Processing Record 11 of Set 2 | lasa
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | areosa
# Processing Record 17 of Set 2 | saint george
# Processing Record 18 of Set 2 | xining
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | tazovskiy
# Processing Record 21 of Set 2 | yakeshi
# Processing Record 22 of Set 2 | safaga
# Processing Record 23 of Set 2 | ocampo
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | helong
# Processing Record 26 of Set 2 | sandomierz
# Processing Record 27 of Set 2 | mareeba
# Processing Record 28 of Set 2 | tabou
# Processing Record 29 of Set 2 | nouadhibou
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | hirara
# Processing Record 32 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 2 | clearwater
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 2 | cap-aux-meules
# Processing Record 39 of Set 2 | olafsvik
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | salalah
# Processing Record 42 of Set 2 | tateyama
# Processing Record 43 of Set 2 | torbay
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 2 | abashiri
# Processing Record 47 of Set 2 | tuatapere
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | brighton
# Processing Record 50 of Set 2 | camacha
# wait
# Processing Record 1 of Set 3 | san cristobal
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | reconquista
# Processing Record 5 of Set 3 | shakawe
# Processing Record 6 of Set 3 | pacific grove
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | port macquarie
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | abalak
# Processing Record 13 of Set 3 | lompoc
# Processing Record 14 of Set 3 | tamadau mare
# Processing Record 15 of Set 3 | phibun mangsahan
# Processing Record 16 of Set 3 | teguise
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | ayan
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | palmer
# Processing Record 22 of Set 3 | yerbogachen
# Processing Record 23 of Set 3 | maniitsoq
# Processing Record 24 of Set 3 | port blair
# Processing Record 25 of Set 3 | kaeo
# Processing Record 26 of Set 3 | araouane
# Processing Record 27 of Set 3 | srandakan
# Processing Record 28 of Set 3 | truth or consequences
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | nabire
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | flinders
# Processing Record 33 of Set 3 | byron bay
# Processing Record 34 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | kavaratti
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | chapayeve
# Processing Record 40 of Set 3 | verkhnevilyuysk
# Processing Record 41 of Set 3 | dalby
# Processing Record 42 of Set 3 | vila franca do campo
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | gondanglegi
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | pilibanga
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | tulun
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | tomatlan
# wait
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | chacabuco
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | ushibuka
# Processing Record 6 of Set 4 | grindavik
# Processing Record 7 of Set 4 | gallup
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 4 | ust-omchug
# Processing Record 11 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | mackenzie
# Processing Record 14 of Set 4 | buala
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | candawaga
# City not found. Skipping...
# Processing Record 18 of Set 4 | shimoda
# Processing Record 19 of Set 4 | tshikapa
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | kupang
# Processing Record 22 of Set 4 | bermeo
# Processing Record 23 of Set 4 | caracoli
# Processing Record 24 of Set 4 | takoradi
# Processing Record 25 of Set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | akyab
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | matara
# Processing Record 33 of Set 4 | banda aceh
# Processing Record 34 of Set 4 | nome
# Processing Record 35 of Set 4 | roma
# Processing Record 36 of Set 4 | batagay
# Processing Record 37 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 4 | channel-port aux basques
# Processing Record 39 of Set 4 | vila
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | barrow
# Processing Record 42 of Set 4 | kiruna
# Processing Record 43 of Set 4 | rio grande
# Processing Record 44 of Set 4 | punta de bombon
# Processing Record 45 of Set 4 | asau
# Processing Record 46 of Set 4 | san jeronimo
# Processing Record 47 of Set 4 | ipixuna
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | sao miguel dos campos
# Processing Record 50 of Set 4 | cap malheureux
# wait
# Processing Record 1 of Set 5 | staryy nadym
# Processing Record 2 of Set 5 | along
# Processing Record 3 of Set 5 | natal
# Processing Record 4 of Set 5 | sagarejo
# Processing Record 5 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 5 | eseka
# Processing Record 7 of Set 5 | lokosovo
# Processing Record 8 of Set 5 | concepcion
# Processing Record 9 of Set 5 | abong mbang
# Processing Record 10 of Set 5 | namli
# Processing Record 11 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 5 | vao
# Processing Record 13 of Set 5 | port-gentil
# Processing Record 14 of Set 5 | lebu
# Processing Record 15 of Set 5 | adrar
# Processing Record 16 of Set 5 | esperance
# Processing Record 17 of Set 5 | jumla
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | itaberai
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | vernon
# Processing Record 22 of Set 5 | mount isa
# Processing Record 23 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 5 | sham churasi
# Processing Record 25 of Set 5 | beian
# Processing Record 26 of Set 5 | miri
# Processing Record 27 of Set 5 | tommot
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 30 of Set 5 | teresopolis
# Processing Record 31 of Set 5 | medicine hat
# Processing Record 32 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 5 | poronaysk
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | imbituba
# Processing Record 36 of Set 5 | pierre
# Processing Record 37 of Set 5 | camana
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | manjacaze
# Processing Record 40 of Set 5 | rosarito
# Processing Record 41 of Set 5 | kalcheva
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | sabang
# Processing Record 44 of Set 5 | otawara
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | kropotkin
# Processing Record 48 of Set 5 | hanyang
# Processing Record 49 of Set 5 | ostrovnoy
# Processing Record 50 of Set 5 | codrington
# wait
# Processing Record 1 of Set 6 | peterhead
# Processing Record 2 of Set 6 | arlit
# Processing Record 3 of Set 6 | yulara
# Processing Record 4 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 6 | boende
# Processing Record 6 of Set 6 | matay
# Processing Record 7 of Set 6 | henties bay
# Processing Record 8 of Set 6 | tezu
# Processing Record 9 of Set 6 | puerto del rosario
# Processing Record 10 of Set 6 | guaira
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 6 | tibati
# Processing Record 14 of Set 6 | saskylakh
# Processing Record 15 of Set 6 | kahului
# Processing Record 16 of Set 6 | coos bay
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | chameza
# City not found. Skipping...
# Processing Record 19 of Set 6 | fuxin
# Processing Record 20 of Set 6 | agadir
# Processing Record 21 of Set 6 | rio gallegos
# Processing Record 22 of Set 6 | camopi
# Processing Record 23 of Set 6 | sola
# Processing Record 24 of Set 6 | la palma
# Processing Record 25 of Set 6 | turkan
# Processing Record 26 of Set 6 | coari
# Processing Record 27 of Set 6 | mazatlan
# Processing Record 28 of Set 6 | grand-lahou
# Processing Record 29 of Set 6 | burns lake
# Processing Record 30 of Set 6 | aberdeen
# Processing Record 31 of Set 6 | port augusta
# Processing Record 32 of Set 6 | nainpur
# Processing Record 33 of Set 6 | shorkot
# Processing Record 34 of Set 6 | hofn
# Processing Record 35 of Set 6 | saint-philippe
# Processing Record 36 of Set 6 | fairbanks
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | beringovskiy
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | avera
# Processing Record 41 of Set 6 | cabo san lucas
# Processing Record 42 of Set 6 | lakes entrance
# Processing Record 43 of Set 6 | zhangjiakou
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | halifax
# Processing Record 46 of Set 6 | berbera
# Processing Record 47 of Set 6 | mount gambier
# Processing Record 48 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 6 | ambilobe
# Processing Record 50 of Set 6 | sao felix do xingu
# wait
# Processing Record 1 of Set 7 | mehamn
# Processing Record 2 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 7 | tabuk
# Processing Record 5 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 6 of Set 7 | bekhtery
# Processing Record 7 of Set 7 | ust-maya
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | axim
# Processing Record 10 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 7 | victoria
# Processing Record 12 of Set 7 | borzoy
# Processing Record 13 of Set 7 | gerash
# Processing Record 14 of Set 7 | viedma
# Processing Record 15 of Set 7 | kalulushi
# Processing Record 16 of Set 7 | lazaro cardenas
# Processing Record 17 of Set 7 | tura
# Processing Record 18 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 7 | boa vista
# Processing Record 20 of Set 7 | cascais
# Processing Record 21 of Set 7 | ikalamavony
# Processing Record 22 of Set 7 | dryden
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | noumea
# Processing Record 25 of Set 7 | rockland
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 28 of Set 7 | pozo colorado
# Processing Record 29 of Set 7 | taltal
# Processing Record 30 of Set 7 | mizan teferi
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | port saint john
# Processing Record 33 of Set 7 | milas
# Processing Record 34 of Set 7 | hasaki
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | maryville
# Processing Record 37 of Set 7 | huarmey
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | windhoek
# Processing Record 40 of Set 7 | sao jose da coroa grande
# Processing Record 41 of Set 7 | kirakira
# Processing Record 42 of Set 7 | plettenberg bay
# Processing Record 43 of Set 7 | aykhal
# Processing Record 44 of Set 7 | batagay-alyta
# Processing Record 45 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 7 | dabat
# Processing Record 47 of Set 7 | vestmannaeyjar
# Processing Record 48 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 7 | pisco
# wait
# Processing Record 1 of Set 8 | san andres
# Processing Record 2 of Set 8 | vostok
# Processing Record 3 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 8 | saint marys
# Processing Record 5 of Set 8 | fiumicino
# Processing Record 6 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 7 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 8 of Set 8 | buta
# Processing Record 9 of Set 8 | kinango
# Processing Record 10 of Set 8 | kamenka
# Processing Record 11 of Set 8 | zhongshu
# Processing Record 12 of Set 8 | minna
# Processing Record 13 of Set 8 | kalachinsk
# Processing Record 14 of Set 8 | kedrovyy
# Processing Record 15 of Set 8 | hoquiam
# Processing Record 16 of Set 8 | puerto madryn
# Processing Record 17 of Set 8 | conde
# Processing Record 18 of Set 8 | chokurdakh
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | nur
# Processing Record 21 of Set 8 | chake chake
# Processing Record 22 of Set 8 | dinguiraye
# Processing Record 23 of Set 8 | deputatskiy
# Processing Record 24 of Set 8 | nizhniy kuranakh
# Processing Record 25 of Set 8 | mahajanga
# Processing Record 26 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 8 | pangkalanbuun
# Processing Record 28 of Set 8 | buraydah
# Processing Record 29 of Set 8 | ballina
# Processing Record 30 of Set 8 | bereda
# Processing Record 31 of Set 8 | katsuura
# Processing Record 32 of Set 8 | najran
# Processing Record 33 of Set 8 | hokitika
# Processing Record 34 of Set 8 | aksarka
# Processing Record 35 of Set 8 | waris aliganj
# Processing Record 36 of Set 8 | grevesmuhlen
# Processing Record 37 of Set 8 | svetlyy
# Processing Record 38 of Set 8 | shitanjing
# Processing Record 39 of Set 8 | raudeberg
# Processing Record 40 of Set 8 | umea
# Processing Record 41 of Set 8 | uruburetama
# Processing Record 42 of Set 8 | touros
# Processing Record 43 of Set 8 | zyryanka
# Processing Record 44 of Set 8 | porto belo
# Processing Record 45 of Set 8 | hollola
# Processing Record 46 of Set 8 | katherine
# Processing Record 47 of Set 8 | ulmeni
# Processing Record 48 of Set 8 | huizen
# Processing Record 49 of Set 8 | waipawa
# Processing Record 50 of Set 8 | basco
# wait
# Processing Record 1 of Set 9 | sandy bay
# Processing Record 2 of Set 9 | puksoozero
# Processing Record 3 of Set 9 | karibib
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | novoilinsk
# Processing Record 6 of Set 9 | crestview
# Processing Record 7 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 8 of Set 9 | itarema
# Processing Record 9 of Set 9 | zinder
# Processing Record 10 of Set 9 | alofi
# Processing Record 11 of Set 9 | kingsport
# Processing Record 12 of Set 9 | ucluelet
# Processing Record 13 of Set 9 | zyryanskoye
# Processing Record 14 of Set 9 | hualmay
# Processing Record 15 of Set 9 | trinidad
# Processing Record 16 of Set 9 | ginda
# Processing Record 17 of Set 9 | nan
# Processing Record 18 of Set 9 | shaoyang
# Processing Record 19 of Set 9 | campos belos
# Processing Record 20 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | agdam
# Processing Record 23 of Set 9 | iranshahr
# Processing Record 24 of Set 9 | sakakah
# Processing Record 25 of Set 9 | labuhan
# Processing Record 26 of Set 9 | ekhabi
# Processing Record 27 of Set 9 | kichera
# Processing Record 28 of Set 9 | whitecourt
# Processing Record 29 of Set 9 | valparaiso
# Processing Record 30 of Set 9 | naron
# Processing Record 31 of Set 9 | azua
# Processing Record 32 of Set 9 | ulety
# Processing Record 33 of Set 9 | sioux lookout
# Processing Record 34 of Set 9 | palu
# Processing Record 35 of Set 9 | klamath falls
# Processing Record 36 of Set 9 | marsh harbour
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | faya
# Processing Record 39 of Set 9 | charters towers
# Processing Record 40 of Set 9 | juneau
# Processing Record 41 of Set 9 | kavieng
# Processing Record 42 of Set 9 | lumeje
# Processing Record 43 of Set 9 | bobo dioulasso
# Processing Record 44 of Set 9 | uni
# Processing Record 45 of Set 9 | beidao
# Processing Record 46 of Set 9 | puerto maldonado
# Processing Record 47 of Set 9 | lodja
# Processing Record 48 of Set 9 | port hedland
# Processing Record 49 of Set 9 | talnakh
# Processing Record 50 of Set 9 | poole
# wait
# Processing Record 1 of Set 10 | mildura
# Processing Record 2 of Set 10 | meulaboh
# Processing Record 3 of Set 10 | zabol
# Processing Record 4 of Set 10 | mtinko
# Processing Record 5 of Set 10 | baykit
# Processing Record 6 of Set 10 | havoysund
# Processing Record 7 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 8 of Set 10 | batemans bay
# Processing Record 9 of Set 10 | masuda
# Processing Record 10 of Set 10 | nelson bay
# Processing Record 11 of Set 10 | naze
# Processing Record 12 of Set 10 | rocha
# Processing Record 13 of Set 10 | iskateley
# Processing Record 14 of Set 10 | port hardy
# Processing Record 15 of Set 10 | semiluki
# Processing Record 16 of Set 10 | egvekinot
# Processing Record 17 of Set 10 | grafenhainichen
# Processing Record 18 of Set 10 | rock sound
# Processing Record 19 of Set 10 | monroe
# Processing Record 20 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 10 | mandi bahauddin
# Processing Record 22 of Set 10 | chuy
# Processing Record 23 of Set 10 | dhamtari
# Processing Record 24 of Set 10 | chernyshevskiy
# Processing Record 25 of Set 10 | fairlie
# Processing Record 26 of Set 10 | dalhousie
# Processing Record 27 of Set 10 | kazanskoye
# Processing Record 28 of Set 10 | nioro
# Processing Record 29 of Set 10 | gizo
# Processing Record 30 of Set 10 | mayo
# Processing Record 31 of Set 10 | la victoria
# Processing Record 32 of Set 10 | northam
# Processing Record 33 of Set 10 | ossora
# Processing Record 34 of Set 10 | lulea
# Processing Record 35 of Set 10 | langsa
# Processing Record 36 of Set 10 | ngunguru
# Processing Record 37 of Set 10 | saint-louis
# Processing Record 38 of Set 10 | chester
# Processing Record 39 of Set 10 | crossville
# Processing Record 40 of Set 10 | bosaso
# Processing Record 41 of Set 10 | zhigansk
# Processing Record 42 of Set 10 | port moresby
# Processing Record 43 of Set 10 | chany
# Processing Record 44 of Set 10 | sakaiminato
# Processing Record 45 of Set 10 | el fuerte
# Processing Record 46 of Set 10 | angra
# City not found. Skipping...
# Processing Record 47 of Set 10 | tynda
# Processing Record 48 of Set 10 | havre-saint-pierre
# Processing Record 49 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 50 of Set 10 | grand gaube
# wait
# Processing Record 1 of Set 11 | lazdijai
# Processing Record 2 of Set 11 | clyde river
# Processing Record 3 of Set 11 | richards bay
# Processing Record 4 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 11 | borama
# City not found. Skipping...
# Processing Record 6 of Set 11 | dehloran
# Processing Record 7 of Set 11 | cayenne
# Processing Record 8 of Set 11 | tautira
# Processing Record 9 of Set 11 | wuchang
# Processing Record 10 of Set 11 | princeville
# Processing Record 11 of Set 11 | balaipungut
# Processing Record 12 of Set 11 | la florida
# Processing Record 13 of Set 11 | jian
# Processing Record 14 of Set 11 | bolu
# Processing Record 15 of Set 11 | aknada
# Processing Record 16 of Set 11 | vanavara
# Processing Record 17 of Set 11 | yuanping
# Processing Record 18 of Set 11 | takhli
# Processing Record 19 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 20 of Set 11 | kabanjahe
# Processing Record 21 of Set 11 | drakino
# Processing Record 22 of Set 11 | andenes
# Processing Record 23 of Set 11 | vikhorevka
# Processing Record 24 of Set 11 | kenai
# Processing Record 25 of Set 11 | severobaykalsk
# Processing Record 26 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 27 of Set 11 | dong xoai
# Processing Record 28 of Set 11 | petatlan
# Processing Record 29 of Set 11 | punta gorda
# Processing Record 30 of Set 11 | tieling
# Processing Record 31 of Set 11 | rozmital pod tremsinem
# Processing Record 32 of Set 11 | santa lucia
# Processing Record 33 of Set 11 | sompeta
# Processing Record 34 of Set 11 | lethem
# Processing Record 35 of Set 11 | wenling
# Processing Record 36 of Set 11 | santa rosa
# Processing Record 37 of Set 11 | mabaruma
# Processing Record 38 of Set 11 | khash
# Processing Record 39 of Set 11 | lamlash
# Processing Record 40 of Set 11 | seminole
# Processing Record 41 of Set 11 | lingao
# Processing Record 42 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 11 | pailitas
# Processing Record 44 of Set 11 | cusset
# Processing Record 45 of Set 11 | saint-augustin
# Processing Record 46 of Set 11 | gat
# Processing Record 47 of Set 11 | ust-nera
# Processing Record 48 of Set 11 | kudahuvadhoo
# Processing Record 49 of Set 11 | sabha
# Processing Record 50 of Set 11 | coihaique
# wait
# Processing Record 1 of Set 12 | ponta delgada
# Processing Record 2 of Set 12 | merauke
# Processing Record 3 of Set 12 | shahrud
# Processing Record 4 of Set 12 | college
# Processing Record 5 of Set 12 | dunedin
# Processing Record 6 of Set 12 | sidi bu zayd
# City not found. Skipping...
# Processing Record 7 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 12 | nhulunbuy
# Processing Record 9 of Set 12 | westport
# Processing Record 10 of Set 12 | jieshi
# Processing Record 11 of Set 12 | musoma
# Processing Record 12 of Set 12 | puerto escondido
# Processing Record 13 of Set 12 | arkhangelsk
# Processing Record 14 of Set 12 | zheleznodorozhnyy
# Processing Record 15 of Set 12 | mantua
# Processing Record 16 of Set 12 | heihe
# Processing Record 17 of Set 12 | atasu
# Processing Record 18 of Set 12 | oktyabrskiy
# Processing Record 19 of Set 12 | mocuba
# Processing Record 20 of Set 12 | otake
# Processing Record 21 of Set 12 | ancud
# Processing Record 22 of Set 12 | bubaque
# Processing Record 23 of Set 12 | shellbrook
# Processing Record 24 of Set 12 | chardara
# Processing Record 25 of Set 12 | bilma
# Processing Record 26 of Set 12 | muyezerskiy
# Processing Record 27 of Set 12 | banes
# Processing Record 28 of Set 12 | jaque
# Processing Record 29 of Set 12 | north bend
# Processing Record 30 of Set 12 | kruisfontein
# Processing Record 31 of Set 12 | san juan
# Processing Record 32 of Set 12 | mugur-aksy
# Processing Record 33 of Set 12 | bac lieu
# Processing Record 34 of Set 12 | concepcion del uruguay
# Processing Record 35 of Set 12 | vila velha
# Processing Record 36 of Set 12 | eenhana
# Processing Record 37 of Set 12 | poya
# Processing Record 38 of Set 12 | rampura
# Processing Record 39 of Set 12 | stornoway
# Processing Record 40 of Set 12 | necochea
# Processing Record 41 of Set 12 | tiznit
# Processing Record 42 of Set 12 | gilgit
# Processing Record 43 of Set 12 | murgab
# Processing Record 44 of Set 12 | fujin
# Processing Record 45 of Set 12 | halle
# Processing Record 46 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 12 | ambon
# Processing Record 48 of Set 12 | meadville
# Processing Record 49 of Set 12 | le port
# Processing Record 50 of Set 12 | codajas
# wait
# Processing Record 1 of Set 13 | bilibino
# Processing Record 2 of Set 13 | qiyang
# Processing Record 3 of Set 13 | synya
# Processing Record 4 of Set 13 | dhankuta
# Processing Record 5 of Set 13 | ofaqim
# Processing Record 6 of Set 13 | ongandjera
# Processing Record 7 of Set 13 | geraldton
# Processing Record 8 of Set 13 | narayangarh
# Processing Record 9 of Set 13 | novopskov
# Processing Record 10 of Set 13 | margate
# Processing Record 11 of Set 13 | sao domingos
# Processing Record 12 of Set 13 | gari
# Processing Record 13 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 13 | simoes
# Processing Record 15 of Set 13 | eston
# Processing Record 16 of Set 13 | paamiut
# Processing Record 17 of Set 13 | likhoslavl
# Processing Record 18 of Set 13 | te anau
# Processing Record 19 of Set 13 | kinablangan
# Processing Record 20 of Set 13 | ulaanbaatar
# Processing Record 21 of Set 13 | ca mau
# Processing Record 22 of Set 13 | kenora
# Processing Record 23 of Set 13 | bandarbeyla
# Processing Record 24 of Set 13 | cockburn town
# Processing Record 25 of Set 13 | methoni
# Processing Record 26 of Set 13 | martapura
# Processing Record 27 of Set 13 | aktash
# Processing Record 28 of Set 13 | belyy yar
# Processing Record 29 of Set 13 | half moon bay
# Processing Record 30 of Set 13 | idukki
# Processing Record 31 of Set 13 | athabasca
# Processing Record 32 of Set 13 | seoul
# Processing Record 33 of Set 13 | bollnas
# Processing Record 34 of Set 13 | lincolnton
# Processing Record 35 of Set 13 | san lawrenz
# Processing Record 36 of Set 13 | fengzhen
# Processing Record 37 of Set 13 | tamandare
# Processing Record 38 of Set 13 | ordynskoye
# Processing Record 39 of Set 13 | vanimo
# Processing Record 40 of Set 13 | ahuimanu
# Processing Record 41 of Set 13 | damghan
# Processing Record 42 of Set 13 | ewa beach
# Processing Record 43 of Set 13 | mizdah
# Processing Record 44 of Set 13 | padang
# Processing Record 45 of Set 13 | mehran
# Processing Record 46 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 13 | po
# City not found. Skipping...
# Processing Record 48 of Set 13 | myitkyina
# Processing Record 49 of Set 13 | pangnirtung
# Processing Record 50 of Set 13 | jacksonville
# wait
# Processing Record 1 of Set 14 | moissala
# Processing Record 2 of Set 14 | maragogi
# Processing Record 3 of Set 14 | tessalit
# Processing Record 4 of Set 14 | broken hill
# Processing Record 5 of Set 14 | palencia
# Processing Record 6 of Set 14 | sorland
# Processing Record 7 of Set 14 | burnie
# Processing Record 8 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 14 | bismarck
# Processing Record 10 of Set 14 | terre haute
# Processing Record 11 of Set 14 | pombas
# Processing Record 12 of Set 14 | luanda
# Processing Record 13 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 14 | hobbs
# Processing Record 16 of Set 14 | pemangkat
# Processing Record 17 of Set 14 | petrolandia
# City not found. Skipping...
# Processing Record 18 of Set 14 | kidal
# Processing Record 19 of Set 14 | lerwick
# Processing Record 20 of Set 14 | makarov
# Processing Record 21 of Set 14 | berdigestyakh
# Processing Record 22 of Set 14 | erenhot
# Processing Record 23 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 14 | kizner
# Processing Record 25 of Set 14 | shenjiamen
# Processing Record 26 of Set 14 | haines junction
# Processing Record 27 of Set 14 | qasigiannguit
# Processing Record 28 of Set 14 | voznesenskoye
# Processing Record 29 of Set 14 | turukhansk
# Processing Record 30 of Set 14 | mbekenyera
# Processing Record 31 of Set 14 | montrose
# Processing Record 32 of Set 14 | caravelas
# Processing Record 33 of Set 14 | praya
# Processing Record 34 of Set 14 | nombre de dios
# Processing Record 35 of Set 14 | lafiagi
# Processing Record 36 of Set 14 | zarya
# Processing Record 37 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 14 | coihueco
# Processing Record 39 of Set 14 | maroantsetra
# Processing Record 40 of Set 14 | saint-francois
# Processing Record 41 of Set 14 | biak
# Processing Record 42 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 43 of Set 14 | bhatkal
# Processing Record 44 of Set 14 | tall kayf
# Processing Record 45 of Set 14 | ostroh
# Processing Record 46 of Set 14 | masuguru
# Processing Record 47 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 49 of Set 14 | krasnyy yar
# Processing Record 50 of Set 14 | kirkenaer
# wait
# Processing Record 1 of Set 15 | singkang
# Processing Record 2 of Set 15 | cherepovets
# Processing Record 3 of Set 15 | yekaterinovka
# Processing Record 4 of Set 15 | marathon
# Processing Record 5 of Set 15 | abnub
# Processing Record 6 of Set 15 | chiang klang
# Processing Record 7 of Set 15 | tarnobrzeg
# Processing Record 8 of Set 15 | odweyne
# Processing Record 9 of Set 15 | taoudenni
# Processing Record 10 of Set 15 | nantucket
# Processing Record 11 of Set 15 | la baule-escoublac
# Processing Record 12 of Set 15 | marinette
# Processing Record 13 of Set 15 | izhma
# Processing Record 14 of Set 15 | grande prairie
# Processing Record 15 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 15 | ganzhou
# Processing Record 17 of Set 15 | riyadh
# Processing Record 18 of Set 15 | yamada
# Processing Record 19 of Set 15 | kipini
# Processing Record 20 of Set 15 | tatarsk
# Processing Record 21 of Set 15 | cedar city
# Processing Record 22 of Set 15 | fort-shevchenko
# Processing Record 23 of Set 15 | magdagachi
# Processing Record 24 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 15 | portland
# Processing Record 26 of Set 15 | alyangula
# Processing Record 27 of Set 15 | berlevag
# Processing Record 28 of Set 15 | plyussa
# Processing Record 29 of Set 15 | conceicao da barra
# Processing Record 30 of Set 15 | lahat
# Processing Record 31 of Set 15 | amahai
# Processing Record 32 of Set 15 | samarai
# Processing Record 33 of Set 15 | laguna de perlas
# Processing Record 34 of Set 15 | arcachon
# Processing Record 35 of Set 15 | abu samrah
# Processing Record 36 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 15 | yuzhno-kurilsk
# Processing Record 38 of Set 15 | kushima
# Processing Record 39 of Set 15 | marzuq
# Processing Record 40 of Set 15 | keetmanshoop
# Processing Record 41 of Set 15 | pittsfield
# Processing Record 42 of Set 15 | williston
# Processing Record 43 of Set 15 | hebertville
# City not found. Skipping...
# Processing Record 44 of Set 15 | kuah
# Processing Record 45 of Set 15 | malyye derbety
# Processing Record 46 of Set 15 | emba
# Processing Record 47 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 15 | atikokan
# Processing Record 50 of Set 15 | shache
# wait
# Processing Record 1 of Set 16 | kribi
# Processing Record 2 of Set 16 | rundu
# Processing Record 3 of Set 16 | pitkyaranta
# Processing Record 4 of Set 16 | bud
# Processing Record 5 of Set 16 | katobu
# Processing Record 6 of Set 16 | sawtell
# Processing Record 7 of Set 16 | ratnagiri
# Processing Record 8 of Set 16 | gua musang
# Processing Record 9 of Set 16 | christchurch
# Processing Record 10 of Set 16 | marshall
# Processing Record 11 of Set 16 | hami
# Processing Record 12 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 16 | russell
# Processing Record 14 of Set 16 | solnechnyy
# Processing Record 15 of Set 16 | koungheul
# Processing Record 16 of Set 16 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 16 | namatanai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Hilo  19.7297 -155.0900     72.25        89          46
# 1     Ponta Do Sol  32.6667  -17.1000     61.05        74          94
# 2          Ushuaia -54.8000  -68.3000     33.10        92          31
# 3         Luderitz -26.6481   15.1594     70.43        71           0
# 4      Tuktoyaktuk  69.4541 -133.0374    -34.35       100          71
# 5     Norman Wells  65.2820 -126.8329     -5.84        99         100
# 6      Capinopolis -18.6819  -49.5697     69.55        94           8
# 7  Bambous Virieux -20.3428   57.7575     82.22        86         100
# 8           Dwarka  22.2394   68.9678     70.68        57           0
# 9       Nikolskoye  59.7035   30.7861     36.88        92         100
#
#    Wind Speed Country                 Date       description
# 0        1.01      US  2022-02-14 04:04:46  scattered clouds
# 1        1.77      PT  2022-02-14 04:01:38   overcast clouds
# 2        4.85      AR  2022-02-14 04:05:05  scattered clouds
# 3        8.90      NA  2022-02-14 04:06:06         clear sky
# 4        7.61      CA  2022-02-14 04:06:07     broken clouds
# 5        0.92      CA  2022-02-14 04:06:07   overcast clouds
# 6        3.33      BR  2022-02-14 04:06:08         clear sky
# 7       13.47      MU  2022-02-14 04:06:08        light rain
# 8        4.27      IN  2022-02-14 04:06:09         clear sky
# 9       11.30      RU  2022-02-14 04:06:09   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
